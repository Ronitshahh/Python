# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np 
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Lets First Load the dataset

# %%
dataset = pd.read_excel("SuperStoreUS.xlsx")

# %% [markdown]
# ### Display top 4 rows of the Dataset

# %%
dataset.head(4)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
#
#     Region State or Province         City  Postal Code Order Date  Ship Date  \
# 0     West        Washington    Anacortes        98221 2015-01-07 2015-01-08
# ...

# %% [markdown]
# ### Find the Shape of the Dataset (No. of rows & columns)

# %%
dataset.shape
# Out:
# (1952, 25)

# %% [markdown]
# ### So now you know the number of orders

# %%
print("number of rows",dataset.shape[0])
print("number of columns",dataset.shape[1])
# Out:
# number of rows 1952
# number of columns 25

# %% [markdown]
# ### Now find the missing Values in the given dataset

# %%
dataset.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
dataset['Product Base Margin'].fillna(dataset['Product Base Margin'].mean(),inplace=True)

# %% [markdown]
# ### NOW AGAIN CHECK THE MISSING VALUES IN THE DATASET

# %%
dataset.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Country                 0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %% [markdown]
# ### SO NOW AS WE CAN SEE THERE IS NO NULL VALUES PRESENT IN THE DATASET

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# Low              398
# Not Specified    396
# High             391
# Critical         390
# Medium           376
# Critical           1
# Name: count, dtype: int64

# %%
dataset['Order Priority'].unique()
# Out:
# array(['High', 'Not Specified', 'Critical', 'Medium', 'Low', 'Critical '],
#       dtype=object)

# %% [markdown]
# ### So as you can see there are 2 different objects (critical)

# %%
dataset['Order Priority'] = dataset["Order Priority"].replace("Critical ","Critical")

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# Low              398
# Not Specified    396
# High             391
# Critical         391
# Medium           376
# Name: count, dtype: int64

# %% [markdown]
# ### By replacing the object,you can see the problem is solved

# %%
plt.figure(figsize=(5,4)) #to show the lenght and width 
sns.countplot(x="Order Priority",data=dataset)
plt.title("Count of Order Priority") #to show the title
plt.savefig("Count of Order Priority")
plt.show()

# %% [markdown]
# # So now you can see that with the help of seaborn library we created a countplot

# %% [markdown]
# # SHIP MODE

# %%
dataset["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       1437
# Delivery Truck     275
# Express Air        240
# Name: count, dtype: int64

# %%
x = dataset["Ship Mode"].value_counts().index
y = dataset["Ship Mode"].value_counts().values

# %%
plt.figure(figsize=(5,4))
plt.pie(y,labels=x,startangle= 60,autopct="%0.0f%%") # we can also change the decimal values by replacing 0
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ### As you can see the above classifications are also known as Univariate Analysis
# the other two are bivariate and multi-variate analysis

# %% [markdown]
# ### Univariate analysis is a statistical method that examines each variable in a data set separately.

# %%
### Now we are performing bivariate analysis with product category and shipping mode

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Ship Mode",data=dataset,hue="Product Category")
plt.show()

# %% [markdown]
# ### Customer Segment

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Customer Segment",data=dataset)
plt.show()

# %% [markdown]
# ### As you can see with the help of the above chart that we have the maximum customer from the corporate segment.

# %% [markdown]
# # Product Category

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Product Category",data=dataset)
plt.show()

# %%
# Bivariate analysis of product category and subcategory which consists of Office supply.

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Product Category",data=dataset[dataset["Product Category"]=="Office Supplies"],hue=("Product Sub-Category"))
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='Product Category',y='Profit',data=dataset,estimator='sum')
plt.show()

# %%
### [:5] is used to show the top 5 state or provinces with the most sales

# %%
dataset['State or Province'].value_counts()[:5]
# Out:
# State or Province
# California    214
# New York      129
# Texas         124
# Florida       123
# Illinois       88
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='Product Category',y='Product Base Margin',data=dataset,estimator='sum')
plt.show()

# %%
### scatter plot, line chart, heatmap,Box plot,Histogram
